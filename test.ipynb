# %%
# For reloading modules
# %load_ext autoreload
# %autoreload 2

import numpy as np

# Local imports
from loader import *
from utils import *

monet_path = "dataset/monet/"
photo_path = "dataset/photos/"
photo_path_test = "dataset/test/photos/"

photo_dataset_test = ImageDataset(photo_path_test)


imgs = [photo_dataset_test.get_img(i) for i in range(3)]
show_set_images(imgs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
