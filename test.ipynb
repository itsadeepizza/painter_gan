# %%
# For reloading modules
# %load_ext autoreload
# %autoreload 2

import numpy as np

# Local imports
from loader import *
from utils import *

monet_path = "dataset/monet/"
photo_path = "dataset/photos/"
monet_dataset = ImageDataset(monet_path)

imgs = [monet_dataset.get_img(i) for i in range(4)]
show_set_images(imgs)

photos_dataset = ImageDataset(photo_path)
imgs = [photos_dataset.get_img(i) for i in range(4)]
show_set_images(imgs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
